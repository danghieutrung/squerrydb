# %% [markdown]
# ## Data Loading and Summary

# %%
# !wget https://datasets.imdbws.com/title.basics.tsv.gz
# !wget https://datasets.imdbws.com/title.episode.tsv.gz
# !wget https://datasets.imdbws.com/title.ratings.tsv.gz
# Out:
# --2025-01-20 08:40:09--  https://datasets.imdbws.com/title.basics.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.167.212.123, 3.167.212.55, 3.167.212.77, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.167.212.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 200509675 (191M) [binary/octet-stream]
# Saving to: ‘title.basics.tsv.gz’
#
# title.basics.tsv.gz 100%[===================>] 191.22M   126MB/s    in 1.5s
#
# 2025-01-20 08:40:10 (126 MB/s) - ‘title.basics.tsv.gz’ saved [200509675/200509675]
#
# --2025-01-20 08:40:11--  https://datasets.imdbws.com/title.episode.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.167.212.123, 3.167.212.55, 3.167.212.77, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.167.212.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48224273 (46M) [binary/octet-stream]
# Saving to: ‘title.episode.tsv.gz’
#
# title.episode.tsv.g 100%[===================>]  45.99M  98.4MB/s    in 0.5s
#
# 2025-01-20 08:40:11 (98.4 MB/s) - ‘title.episode.tsv.gz’ saved [48224273/48224273]
#
# --2025-01-20 08:40:11--  https://datasets.imdbws.com/title.ratings.tsv.gz
# Resolving datasets.imdbws.com (datasets.imdbws.com)... 3.167.212.123, 3.167.212.55, 3.167.212.77, ...
# Connecting to datasets.imdbws.com (datasets.imdbws.com)|3.167.212.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7670349 (7.3M) [binary/octet-stream]
# Saving to: ‘title.ratings.tsv.gz’
#
# title.ratings.tsv.g 100%[===================>]   7.31M  40.9MB/s    in 0.2s
#
# 2025-01-20 08:40:11 (40.9 MB/s) - ‘title.ratings.tsv.gz’ saved [7670349/7670349]

# %%
# !gzip -d title.basics.tsv.gz
# !gzip -d title.episode.tsv.gz
# !gzip -d title.ratings.tsv.gz

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd

# %%
basics = pd.read_csv('title.basics.tsv', sep='\t', low_memory=False, na_values=['\\N'])
episode = pd.read_csv('title.episode.tsv', sep='\t', low_memory=False, na_values=['\\N'])
ratings = pd.read_csv('title.ratings.tsv', sep='\t', low_memory=False, na_values=['\\N'])

# %%
basics.head(3)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
#
#    isAdult  startYear  endYear runtimeMinutes                    genres
# 0      0.0     1894.0      NaN              1         Documentary,Short
# 1      0.0     1892.0      NaN              5           Animation,Short
# 2      0.0     1892.0      NaN              5  Animation,Comedy,Romance

# %%
episode.head(3)
# Out:
#       tconst parentTconst  seasonNumber  episodeNumber
# 0  tt0031458   tt32857063           NaN            NaN
# 1  tt0041951    tt0041038           1.0            9.0
# 2  tt0042816    tt0989125           1.0           17.0

# %%
ratings.head(3)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2117
# 1  tt0000002            5.6       285
# 2  tt0000003            6.4      2157

# %%
len(episode), len(basics), len(ratings)
# Out:
# (8754842, 11389318, 1524613)

# %% [markdown]
# ### Checking ID columns for uniqueness

# %%
basics['tconst'].is_unique, episode['tconst'].is_unique, ratings['tconst'].is_unique
# Out:
# (True, True, True)

# %%
# Check if columns 'tConst' and 'parentTconst' in episode have common values
len(set(episode['tconst']).intersection(set(episode['parentTconst'])))
# Out:
# 0

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Cleaning for `basics` Dataset

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
# Checking for null values
basics.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle            19
# originalTitle           19
# isAdult                  1
# startYear          1421908
# endYear           11254612
# runtimeMinutes     7777889
# genres              503208
# dtype: int64

# %%
# view all rows with null values of 'primaryTitle' or originalTitle'
basics[(basics['primaryTitle'].isna()) | (basics['originalTitle'].isna())]
# Out:
#               tconst  titleType primaryTitle originalTitle  isAdult  \
# 1253193   tt10516578      video          NaN           NaN      0.0
# 3428270   tt14510930  tvEpisode          NaN           NaN      0.0
# 4070202   tt15700278  tvEpisode          NaN           NaN      0.0
# 4550901   tt17042812      movie          NaN           NaN      0.0
# 5058312    tt1971246  tvEpisode          NaN           NaN      0.0
# 5253934    tt2067043  tvEpisode          NaN           NaN      0.0
# 5592129   tt21883066  tvEpisode          NaN           NaN      0.0
# 5861484    tt2305914  tvEpisode          NaN           NaN      0.0
# 5861491    tt2305918  tvEpisode          NaN           NaN      0.0
# 7529083   tt31462159  tvEpisode          NaN           NaN      0.0
# 7726112   tt32253130      short          NaN           NaN      0.0
# 8019006   tt33094763  tvEpisode          NaN           NaN      0.0
# 8034637   tt33164817      short          NaN           NaN      0.0
# 8211218    tt3383210      short          NaN           NaN      0.0
# 9496075    tt5746000      short          NaN           NaN      0.0
# 9507653    tt5773048  tvEpisode          NaN           NaN      0.0
# 9508096    tt5774076      movie          NaN           NaN      0.0
# 10727152   tt8473688  tvEpisode          NaN           NaN      0.0
# 10758174   tt8541336  tvEpisode          NaN           NaN      0.0
#
#           startYear  endYear runtimeMinutes                     genres
# 1253193      2017.0      NaN            NaN                Music,Short
# 3428270         NaN      NaN            NaN                        NaN
# 4070202      2021.0      NaN            NaN                  Talk-Show
# 4550901      2010.0      NaN             87                   Thriller
# 5058312      2011.0      NaN            NaN                  Biography
# 5253934      1965.0      NaN            NaN                      Music
# 5592129      2022.0      NaN            NaN             News,Talk-Show
# 5861484         NaN      NaN            NaN           Comedy,Talk-Show
# 5861491         NaN      NaN            NaN           Comedy,Talk-Show
# 7529083      2024.0      NaN            NaN                      Drama
# 7726112         NaN      NaN            NaN            Biography,Short
# 8019006      2019.0      NaN            NaN                      Drama
# 8034637      2024.0      NaN            NaN                      Short
# 8211218      2013.0      NaN             12  Documentary,History,Short
# 9496075      2016.0      NaN             12                      Short
# 9507653      2015.0      NaN            NaN                  Talk-Show
# 9508096      2015.0      NaN            NaN       Action,Drama,Mystery
# 10727152     1987.0      NaN            NaN                      Drama
# 10758174     2018.0      NaN             30         Reality-TV,Romance

# %% [markdown]
# 17 rows have missing values for both `primaryTitle` and `originalTitle` fields. We will remove these rows.

# %%
# Remove rows with null values in 'primaryTitle' and 'originalTitle'
basics = basics.dropna(subset=['primaryTitle', 'originalTitle'])

# %%
# View the only row with missing 'isAdult' value
pd.set_option('max_colwidth', None)
basics[basics['isAdult'].isna()]
# Out:
#              tconst  titleType  \
# 2987657  tt13704268  tvEpisode
#
#                                                                    primaryTitle  \
# 2987657  Bay of the Triffids/Doctor of Doom\tBay of the Triffids/Doctor of Doom
#
#         originalTitle  isAdult  startYear  endYear           runtimeMinutes  \
# 2987657             0      NaN        NaN      NaN  Animation,Comedy,Family
#
#         genres
# 2987657    NaN

# %% [markdown]
# In this case, the `\t` character was intepreted as literal string isntead of a `Tab` seperator.
#
# Instead of removing this row, we fix it by reassigning the `primaryTitle`, `originalTitle`, and `isAdult` fields to their right values:
# - `primaryTitle`: Bay of the Triffids/Doctor of Doom
# - `originalTitle`: Bay of the Triffids/Doctor of Doom
# - isAdult: 0

# %%
basics.loc[2989193, ['primaryTitle', 'originalTitle', 'isAdult']] = ['Bay of the Triffids/Doctor of Doom', 'Bay of the Triffids/Doctor of Doom', 0]
basics.loc[2989193]
# Out:
# tconst                                    tt13707222
# titleType                                      short
# primaryTitle      Bay of the Triffids/Doctor of Doom
# originalTitle     Bay of the Triffids/Doctor of Doom
# isAdult                                          0.0
# startYear                                     2020.0
# endYear                                          NaN
# runtimeMinutes                                    20
# genres                                  Sci-Fi,Short
# Name: 2989193, dtype: object

# %% [markdown]
# Next, we check if all values in the field `isAdult` is either 0 or 1

# %%
basics['isAdult'].value_counts()
# Out:
# isAdult
# 0.0       11020436
# 1.0         368042
# 1978.0         130
# 1985.0          83
# 1980.0          66
# 1979.0          63
# 1984.0          41
# 1974.0          32
# 1982.0          32
# 1972.0          29
# 2015.0          28
# 1966.0          25
# 1983.0          25
# 1968.0          24
# 2016.0          21
# 1977.0          20
# 1975.0          18
# 1973.0          18
# 1976.0          18
# 1981.0          18
# 1986.0          17
# 2017.0          17
# 1987.0          13
# 2020.0           9
# 2018.0           9
# 1967.0           8
# 2013.0           8
# 1969.0           7
# 2019.0           7
# 2023.0           7
# 2014.0           6
# 1988.0           5
# 2024.0           4
# 1970.0           3
# 2022.0           2
# 1971.0           2
# 2011.0           1
# 1964.0           1
# 2021.0           1
# 2012.0           1
# 2005.0           1
# Name: count, dtype: int64

# %% [markdown]
# It seems like the some of the values in the field `isAdult` are year values and should belong to the `startYear` columns instead.
#
# We closely inspect these rows

# %%
basics_isAdult_filter = basics[~basics['isAdult'].isin([0,1])]
basics_isAdult_filter
# Out:
#               tconst  titleType  \
# 1096717   tt10233364  tvEpisode
# 1506173   tt10970874  tvEpisode
# 1893321   tt11670006  tvEpisode
# 2004106   tt11868642  tvEpisode
# 2157353   tt12149332  tvEpisode
# ...              ...        ...
# 8525558   tt35473846  tvEpisode
# 8525574   tt35473863  tvEpisode
# 8717074    tt3984412  tvEpisode
# 11346028   tt9822816  tvEpisode
# 11385778   tt9909210  tvEpisode
#
#                                                                                                                                           primaryTitle  \
# 1096717                                                                                             Rolling in the Deep Dish\tRolling in the Deep Dish
# 1506173     Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?\tDie Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893321                                                                               ...ein angenehmer Unbequemer...\t...ein angenehmer Unbequemer...
# 2004106                     GGN Heavyweight Championship Lungs With Mike Tyson and Snoop\tGGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2157353                                               Jeopardy! College Championship Semifinal Game 3\tJeopardy! College Championship Semifinal Game 3
# ...                                                                                                                                                ...
# 8525558                                                                                                                               X '1963\tX '1963
# 8525574                                                                                                             Reptilicus '1961\tReptilicus '1961
# 8717074   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race\tI'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 11346028        Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan\tZwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 11385778            Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?\tPolitik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#          originalTitle  isAdult  startYear  endYear         runtimeMinutes  \
# 1096717              0   2019.0        NaN      NaN             Reality-TV
# 1506173              0   2019.0        NaN      NaN              Talk-Show
# 1893321              0   1981.0        NaN      NaN            Documentary
# 2004106              0   2020.0        NaN      NaN              Talk-Show
# 2157353              0   2020.0        NaN      NaN       Family,Game-Show
# ...                ...      ...        ...      ...                    ...
# 8525558              0   1985.0        NaN      NaN  Action,Fantasy,Horror
# 8525574              0   1985.0        NaN      NaN  Action,Fantasy,Horror
# 8717074              0   2014.0        NaN      NaN   Game-Show,Reality-TV
# 11346028             0   2019.0        NaN      NaN              Talk-Show
# 11385778             0   2005.0        NaN      NaN              Talk-Show
#
#          genres
# 1096717     NaN
# 1506173     NaN
# 1893321     NaN
# 2004106     NaN
# 2157353     NaN
# ...         ...
# 8525558     NaN
# 8525574     NaN
# 8717074     NaN
# 11346028    NaN
# 11385778    NaN
#
# [821 rows x 9 columns]

# %% [markdown]
# Looks like this is the same issue as before, where the `\t` seperators were intepreted as literal string.
#
# We will check if all these rows contain a `\t` character, and if every row with value of `isAdult` not equal to 0 or 1 have missing `startYear` values

# %%
# Check if every row in basics_isAdult_filter contains `\t` in the primaryTitle
all(basics_isAdult_filter['primaryTitle'].str.contains('\t'))
# Out:
# True

# %%
basics_isAdult_filter['originalTitle'].value_counts()
# Out:
# originalTitle
# 0    819
# 1      2
# Name: count, dtype: int64

# %%
basics_isAdult_filter['startYear'].unique()
# Out:
# array([nan])

# %% [markdown]
# We conclude that for every row where `isAdult` is neither 0 nor 1:
#
# - Every value in `primaryTitle` contains '\t', which should be the `Tab` separator
# - Every value in `originalTitle` is either 0 or 1, which should belong in the `isAdult` column
# - Every value in `startYear` is missing, which is currently in the `isAdult` column

# %% [markdown]
# We will fix these rows by:
# - Splitting all titles in `primaryTitle` by the `\t` character into `primaryTitle` and `originalTitle`
# - Moving all current values in `originalTitle`, which are 0 or 1, to the `isAdult` field
# - Moving all current values in `originalTitle` (e.g 1985, 1986) to the `startYear` field

# %%
# pd.set_option('mode.chained_assignment', None)
basics_isAdult_filter['startYear'] = basics_isAdult_filter['isAdult']
basics_isAdult_filter['isAdult'] = basics_isAdult_filter['originalTitle']
basics_isAdult_filter[['primaryTitle', 'originalTitle']] = basics_isAdult_filter['primaryTitle'].str.split('\t', expand=True)
basics_isAdult_filter
# Out:
# <ipython-input-22-2e15d070df65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter['startYear'] = basics_isAdult_filter['isAdult']
# <ipython-input-22-2e15d070df65>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter['isAdult'] = basics_isAdult_filter['originalTitle']
# <ipython-input-22-2e15d070df65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_isAdult_filter[['primaryTitle', 'originalTitle']] = basics_isAdult_filter['primaryTitle'].str.split('\t', expand=True)
#               tconst  titleType  \
# 1096717   tt10233364  tvEpisode
# 1506173   tt10970874  tvEpisode
# 1893321   tt11670006  tvEpisode
# 2004106   tt11868642  tvEpisode
# 2157353   tt12149332  tvEpisode
# ...              ...        ...
# 8525558   tt35473846  tvEpisode
# 8525574   tt35473863  tvEpisode
# 8717074    tt3984412  tvEpisode
# 11346028   tt9822816  tvEpisode
# 11385778   tt9909210  tvEpisode
#
#                                                                    primaryTitle  \
# 1096717                                                Rolling in the Deep Dish
# 1506173    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893321                                         ...ein angenehmer Unbequemer...
# 2004106            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2157353                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 8525558                                                                 X '1963
# 8525574                                                        Reptilicus '1961
# 8717074   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 11346028     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 11385778       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#                                                                   originalTitle  \
# 1096717                                                Rolling in the Deep Dish
# 1506173    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893321                                         ...ein angenehmer Unbequemer...
# 2004106            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2157353                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 8525558                                                                 X '1963
# 8525574                                                        Reptilicus '1961
# 8717074   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 11346028     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 11385778       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#          isAdult  startYear  endYear         runtimeMinutes genres
# 1096717        0     2019.0      NaN             Reality-TV    NaN
# 1506173        0     2019.0      NaN              Talk-Show    NaN
# 1893321        0     1981.0      NaN            Documentary    NaN
# 2004106        0     2020.0      NaN              Talk-Show    NaN
# 2157353        0     2020.0      NaN       Family,Game-Show    NaN
# ...          ...        ...      ...                    ...    ...
# 8525558        0     1985.0      NaN  Action,Fantasy,Horror    NaN
# 8525574        0     1985.0      NaN  Action,Fantasy,Horror    NaN
# 8717074        0     2014.0      NaN   Game-Show,Reality-TV    NaN
# 11346028       0     2019.0      NaN              Talk-Show    NaN
# 11385778       0     2005.0      NaN              Talk-Show    NaN
#
# [821 rows x 9 columns]

# %%
# Replace the rows in the original DataFrame
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

basics.loc[basics_isAdult_filter.index] = basics_isAdult_filter
basics.head(3)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
#
#   isAdult  startYear  endYear runtimeMinutes                    genres
# 0     0.0     1894.0      NaN              1         Documentary,Short
# 1     0.0     1892.0      NaN              5           Animation,Short
# 2     0.0     1892.0      NaN              5  Animation,Comedy,Romance

# %%
basics['isAdult'] = pd.to_numeric(basics['isAdult'])

# %%
basics.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle             0
# originalTitle            0
# isAdult                  0
# startYear          1421084
# endYear           11254593
# runtimeMinutes     7777874
# genres              503207
# dtype: int64

# %% [markdown]
# There are still missing values in `startYear`, `endYear`, `runtimeMinute`, and `genres`. However, these fields are not mandatory and we can safely ignore these missing values.
#
# Inspect rows with missing values and ensure they are valid

# %%
basics[basics.startYear.isna()]
# Out:
#              tconst  titleType                          primaryTitle  \
# 619       tt0000624      short                     The Ugly Duckling
# 65745     tt0067098  tvEpisode                           Willi Forst
# 83788     tt0085677  tvEpisode                          High Country
# 90911     tt0092975  tvEpisode         Erste Liebe und Heiratssachen
# 90957     tt0093025      movie            Tales of the Brothers Quay
# ...             ...        ...                                   ...
# 11389206  tt9916616      short                                Terror
# 11389208  tt9916620      movie                     The Copeland Case
# 11389222  tt9916652      short      Untitled well- being Documentary
# 11389228  tt9916664      short  Untitled Land Army Girls Documentary
# 11389246  tt9916702      short         Loving London: The Playground
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 619                          The Ugly Duckling      0.0        NaN      NaN
# 65745                              Willi Forst      0.0        NaN      NaN
# 83788                             High Country      0.0        NaN      NaN
# 90911            Erste Liebe und Heiratssachen      0.0        NaN      NaN
# 90957           The Films of the Brothers Quay      0.0        NaN      NaN
# ...                                        ...      ...        ...      ...
# 11389206                                Terror      0.0        NaN      NaN
# 11389208                     The Copeland Case      0.0        NaN      NaN
# 11389222      Untitled well- being Documentary      0.0        NaN      NaN
# 11389228  Untitled Land Army Girls Documentary      0.0        NaN      NaN
# 11389246         Loving London: The Playground      0.0        NaN      NaN
#
#          runtimeMinutes                 genres
# 619                 NaN                  Short
# 65745                55                    NaN
# 83788               NaN                  Sport
# 90911               NaN            Documentary
# 90957                78  Animation,Documentary
# ...                 ...                    ...
# 11389206             13            Drama,Short
# 11389208            NaN                  Drama
# 11389222            NaN                  Short
# 11389228            NaN                  Short
# 11389246            NaN            Drama,Short
#
# [1421084 rows x 9 columns]

# %% [markdown]
# Now that all values in `primaryTitle`, `originalTitle`, `isAdult` fields have been reassigned and moved to their corresponding field, we will filter out all adult movies, which have `isAdult` equal to 1

# %%
# Remove all rows with 'isAdult' = 1
basics = basics[basics['isAdult'] == 0]
basics['isAdult'].value_counts()
# Out:
# isAdult
# 0.0    11021255
# Name: count, dtype: int64

# %% [markdown]
# Finally, we reformat the `genres` column by adding a whitespace `\s` after every comma `,`

# %%
basics['genres'] = basics['genres'].str.replace(r',', r', ')
basics['genres'].head(3)
# Out:
# 0            Documentary, Short
# 1              Animation, Short
# 2    Animation, Comedy, Romance
# Name: genres, dtype: object

# %% [markdown]
# Check all column types

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %% [markdown]
# Convert `float64` into `int64`

# %%
basics["isAdult"] = pd.to_numeric(basics["isAdult"], errors="coerce").astype("Int64")
basics["startYear"] = pd.to_numeric(basics["startYear"], errors="coerce").astype("Int64")
basics["endYear"] = pd.to_numeric(basics["endYear"], errors="coerce").astype("Int64")
basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult            Int64
# startYear          Int64
# endYear            Int64
# runtimeMinutes    object
# genres            object
# dtype: object

# %% [markdown]
# Column `runtimeMinutes` should be type `Int64`

# %%
basics['runtimeMinutes'].unique()
# Out:
# array(['1', '5', '12', '45', '2', nan, '3', '100', '13', '6', '4', '40',
#        '11', '9', '10', '15', '21', '16', '8', '14', '7', '24', '17',
#        '70', '90', '20', '25', '120', '36', '18', '30', '19', '44', '38',
#        '58', '22', '33', '50', '34', '28', '35', '42', '23', '51', '52',
#        '60', '92', '56', '26', '53', '31', '41', '48', '47', '68', '29',
#        '71', '43', '46', '27', '32', '76', '113', '55', '150', '300',
#        '121', '89', '37', '69', '54', '64', '96', '49', '61', '39', '101',
#        '57', '99', '110', '85', '88', '86', '170', '63', '72', '78', '75',
#        '450', '148', '80', '124', '220', '59', '112', '1428', '84', '65',
#        '74', '105', '310', '73', '82', '81', '199', '139', '109', '67',
#        '219', '195', '440', '77', '293', '97', '79', '62', '66', '250',
#        '421', '360', '180', '93', '163', '400', '95', '165', '83', '116',
#        '320', '125', '127', '138', '460', '350', '374', '480', '330',
#        '87', '130', '108', '600', '240', '117', '410', '135', '146',
#        '104', '418', '106', '242', '223', '489', '102', '200', '98',
#        '119', '122', '115', '207', '166', '238', '111', '145', '131',
#        '243', '133', '172', '167', '103', '94', '355', '206', '91', '157',
#        '107', '248', '235', '184', '118', '114', '380', '128', '143',
#        '155', '137', '183', '210', '136', '417', '141', '162', '153',
#        '129', '123', '151', '182', '140', '359', '126', '132', '179',
#        '260', '230', '168', '160', '144', '159', '185', '156', '215',
#        '177', '213', '149', '225', '147', '266', '152', '217', '158',
#        '226', '134', '194', '216', '227', '231', '218', '246', '281',
#        '208', '228', '229', '212', '236', '306', '257', '245', '197',
#        '255', '142', '323', '305', '328', '176', '232', '258', '256',
#        '303', '308', '224', '294', '268', '204', '298', '299', '264',
#        '211', '302', '263', '265', '205', '154', '237', '285', '269',
#        '267', '247', '186', '241', '289', '283', '290', '270', '251',
#        '278', '196', '279', '261', '275', '280', '244', '189', '169',
#        '284', '295', '201', '221', '192', '252', '171', '193', '287',
#        '361', '175', '174', '173', '315', '190', '164', '239', '178',
#        '161', '181', '188', '497', '327', '317', '191', '209', '434',
#        '234', '288', '438', '393', '378', '316', '340', '203', '253',
#        '344', '540', '476', '451', '321', '348', '890', '309', '653',
#        '431', '390', '202', '187', '370', '396', '282', '467', '286',
#        '763', '770', '311', '500', '373', '596', '750', '273', '442',
#        '599', '333', '614', '385', '780', '510', '271', '274', '262',
#        '420', '291', '366', '742', '676', '673', '358', '301', '233',
#        '198', '752', '504', '720', '520', '313', '413', '700', '222',
#        '391', '428', '437', '416', '367', '566', '569', '371', '376',
#        '870', '312', '407', '331', '375', '436', '353', '357', '873',
#        '1290', '345', '318', '335', '624', '398', '272', '567', '606',
#        '214', '384', '501', '834', '254', '522', '276', '439', '314',
#        '515', '620', '528', '336', '341', '568', '571', '556', '386',
#        '383', '650', '343', '277', '698', '401', '377', '672', '465',
#        '622', '296', '1352', '1320', '395', '583', '665', '339', '415',
#        '259', '351', '1620', '388', '325', '455', '554', '612', '616',
#        '349', '659', '458', '426', '660', '1500', '475', '778', '1080',
#        '485', '495', '347', '382', '1800', '577', '1440', '307', '2800',
#        '491', '338', '840', '406', '776', '369', '297', '804', '445',
#        '960', '615', '392', '663', '693', '580', '425', '544', '5220',
#        '464', '545', '640', '446', '372', '629', '678', '1300', '352',
#        '689', '793', '2925', '608', '2880', '1170', '0', '462', '701',
#        '657', '249', '346', '468', '738', '1970', '551', '1260', '1020',
#        '1200', '646', '459', '579', '820', '704', '630', '408', '999',
#        '402', '715', '514', '1664', '1215', '625', '1710', '1035', '550',
#        '1370', '1350', '1410', '1380', '326', '1100', '730', '364', '516',
#        '705', '1196', '443', '765', '2001', '1000', '502', '8400', '541',
#        '2000', '1999', '594', '414', '652', '1040', '1442', '598', '354',
#        '526', '487', '1773', '1932', '466', '4800', '363', '3900', '2150',
#        '403', '900', '552', '381', '527', '636', '575', '519', '379',
#        '530', '412', '506', '547', '800', '441', '469', '719', '429',
#        '1441', '490', 'Reality-TV', '784', '474', '990', '3285', '669',
#        '3300', '319', '1400', '10062', '332', '585', '334', '2160',
#        'Talk-Show', '623', '525', '368', '337', '634', '2004', '570',
#        'Documentary', '13319', '1325', '404', '2020', '324', '409', '304',
#        '478', '472', '329', '35791', 'Family,Game-Show', '1444', '479',
#        '28643', '1845', '675', '1682', '1445', '292', '362', '1174',
#        '1050', '943', '933', '435', '498', '521', '2010', '1099', '483',
#        '668', '785', '6000', '449', '422', '496', '518', '539', '702',
#        '399', '712', '619', 'Animation,Comedy,Family', '512', '950',
#        '559', '736', '470', '444', '405', '830', '883', '387', '454',
#        '432', '457', '447', '453', '942', '452', '3087', '593', '365',
#        '503', '602', '481', '586', '397', '1452', '1554', '499', '542',
#        '850', '562', '2580', '507', '961', '641', '964', '342', '2520',
#        '885', '1268', '1134', '691', '1873', '1860', '572', '783', '509',
#        '2021', '553', '494', '711', '484', '901', '930', '546', '7200',
#        '427', '3720', '1973', '493', '3000', '1560', '1680', '394', '508',
#        '356', '605', '680', '1568', '751', '5700', '590', '845', '717',
#        '998', '853', '2400', '1669', '558', '322', '1210', '771', '655',
#        '865', '588', '488', '695', '970', '456', '12000', '463', '565',
#        '642', '4869', '2252', '1700', '2460', '899', '842', '9000', '613',
#        '411', '696', '758', '803', '1234', '610', '582', '645', '461',
#        '707', '473', '810', '1005', '578', '14400', 'News,Talk-Show',
#        '1087', '1140', '912', 'Comedy,News,Talk-Show', '1415', '1026',
#        '709', '532', '1504', '536', '448', '741',
#        'Documentary,Reality-TV', '424', '1034', '685', '560', '505',
#        '17280', '59460', '852', '471', '632', '535', '1584', '11541',
#        '764', '1044', 'Comedy,Drama,Fantasy', '723', '654', '1262', '537',
#        '1011', '948', '1084', '1002', '1421', 'Fantasy,Horror,Mystery',
#        '1349', '799', '1464', '910', '819', '37440', '904',
#        'Action,Fantasy,Horror', 'Action,Horror,Mystery', '1784', '2005',
#        '2007', '670', '2030', 'Comedy,Drama,Horror', '913', '2027',
#        'Action,Adventure,Drama', '871', '1576', '1229', '661', 'Music',
#        '587', '744', '524', '869', '884', '777', '679', '792', '482',
#        '1056', '2695', '2867', '1511', '1663', '1175', '972', '833',
#        '389', '847', '893', '965', '856', '430', '1384', '1209', '2840',
#        '1143', '874', '529', '1557', '781', '924', '534', '786', '791',
#        '716', '1470', '477', '607', '1763', '1657', '1052', '1339', '643',
#        '626', '1096', 'Drama,Fantasy,Horror', '1155', '1411', '1716',
#        '2288', '3077', '419', '543', '43200', '936', '747',
#        'Game-Show,Reality-TV', '1008', '1285', '2565', '1495', '1151',
#        '740', '549', '1644', '627', '714', '3240', '2905', '5460', '1068',
#        '433', '684', '662', '597', '1559', '914', '1616', '2070', '789',
#        '4162', '3825', '697', '2015', '773', '1329', '1416', '548',
#        '5760', '3692080', '746', '1184', '1179', '486', '423', '51420',
#        '531', '601', '1750', '808', '1755', '1980', '2112', '690', '755',
#        '721', '795', '3600', '2088'], dtype=object)

# %% [markdown]
# Looks like there are text in `runtimeMinutes` that should belong to `genres`

# %%
misplaced_genres = ['Reality-TV', 'Talk-Show', 'Documentary','Family,Game-Show','Animation,Comedy,Family','News,Talk-Show','Comedy,News,Talk-Show','Documentary,Reality-TV','Comedy,Drama,Fantasy','Fantasy,Horror,Mystery','Action,Fantasy,Horror', 'Action,Horror,Mystery','Comedy,Drama,Horror','Action,Adventure,Drama','Drama,Fantasy,Horror','Game-Show,Reality-TV']
basics_misplaced_genres = basics[basics['runtimeMinutes'].isin(misplaced_genres)]
basics_misplaced_genres
# Out:
#               tconst  titleType  \
# 1096717   tt10233364  tvEpisode
# 1506173   tt10970874  tvEpisode
# 1893321   tt11670006  tvEpisode
# 2004106   tt11868642  tvEpisode
# 2157353   tt12149332  tvEpisode
# ...              ...        ...
# 8525558   tt35473846  tvEpisode
# 8525574   tt35473863  tvEpisode
# 8717074    tt3984412  tvEpisode
# 11346028   tt9822816  tvEpisode
# 11385778   tt9909210  tvEpisode
#
#                                                                    primaryTitle  \
# 1096717                                                Rolling in the Deep Dish
# 1506173    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893321                                         ...ein angenehmer Unbequemer...
# 2004106            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2157353                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 8525558                                                                 X '1963
# 8525574                                                        Reptilicus '1961
# 8717074   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 11346028     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 11385778       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#                                                                   originalTitle  \
# 1096717                                                Rolling in the Deep Dish
# 1506173    Die Bauhaus-Stadt Tel Aviv - Vorbild für die Metropolen der Moderne?
# 1893321                                         ...ein angenehmer Unbequemer...
# 2004106            GGN Heavyweight Championship Lungs With Mike Tyson and Snoop
# 2157353                         Jeopardy! College Championship Semifinal Game 3
# ...                                                                         ...
# 8525558                                                                 X '1963
# 8525574                                                        Reptilicus '1961
# 8717074   I'm Not Going to Come Last, I'm Just Going to Die on The Amazing Race
# 11346028     Zwischen Vertuschung und Aufklärung - Missbrauchsgipfel im Vatikan
# 11385778       Politik und/oder Moral - Wie weit geht das Vertrauen der Bürger?
#
#           isAdult  startYear  endYear         runtimeMinutes genres
# 1096717         0       2019     <NA>             Reality-TV    NaN
# 1506173         0       2019     <NA>              Talk-Show    NaN
# 1893321         0       1981     <NA>            Documentary    NaN
# 2004106         0       2020     <NA>              Talk-Show    NaN
# 2157353         0       2020     <NA>       Family,Game-Show    NaN
# ...           ...        ...      ...                    ...    ...
# 8525558         0       1985     <NA>  Action,Fantasy,Horror    NaN
# 8525574         0       1985     <NA>  Action,Fantasy,Horror    NaN
# 8717074         0       2014     <NA>   Game-Show,Reality-TV    NaN
# 11346028        0       2019     <NA>              Talk-Show    NaN
# 11385778        0       2005     <NA>              Talk-Show    NaN
#
# [818 rows x 9 columns]

# %% [markdown]
# Move these values to the correct field, leave `runtimeMinutes` as `nan`

# %%
basics_misplaced_genres['genres'] = basics_misplaced_genres['runtimeMinutes']
basics_misplaced_genres['runtimeMinutes'] = float('nan')
basics.loc[basics_misplaced_genres.index] = basics_misplaced_genres
# Out:
# <ipython-input-33-57f50934d59d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_misplaced_genres['genres'] = basics_misplaced_genres['runtimeMinutes']
# <ipython-input-33-57f50934d59d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics_misplaced_genres['runtimeMinutes'] = float('nan')

# %% [markdown]
# Cast `runtimeMinutes` to `Int64`

# %%
basics["runtimeMinutes"] = pd.to_numeric(basics["runtimeMinutes"], errors="coerce").astype("Int64")

# %%
basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult            Int64
# startYear          Int64
# endYear            Int64
# runtimeMinutes     Int64
# genres            object
# dtype: object

# %% [markdown]
# Final missing values and column type check

# %%
basics.isna().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle             0
# originalTitle            0
# isAdult                  0
# startYear          1419781
# endYear           10887267
# runtimeMinutes     7552951
# genres              499327
# dtype: int64

# %% [markdown]
# ### Data Cleaning for `episode` Dataset

# %%
episode.dtypes
# Out:
# tconst            object
# parentTconst      object
# seasonNumber     float64
# episodeNumber    float64
# dtype: object

# %%
episode.isna().sum()
# Out:
# tconst                 0
# parentTconst           0
# seasonNumber     1776157
# episodeNumber    1776157
# dtype: int64

# %% [markdown]
# Remove all rows with missing `seasonNumber` or `episodeNumber`

# %%
episode.dropna(inplace=True)
episode.isna().sum()
# Out:
# tconst           0
# parentTconst     0
# seasonNumber     0
# episodeNumber    0
# dtype: int64

# %%
episode['seasonNumber'] = episode['seasonNumber'].astype(int)
episode['episodeNumber'] = episode['episodeNumber'].astype(int)
episode.dtypes
# Out:
# tconst           object
# parentTconst     object
# seasonNumber      int64
# episodeNumber     int64
# dtype: object

# %% [markdown]
# ### Data Cleaning for `ratings` Dataset

# %%
ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %% [markdown]
# ## Data Export for SquerryDB GraphQL

# %%
# Merge basics and ratings
all_ratings = pd.merge(basics, ratings, on='tconst', how='inner')
print(all_ratings.shape)

# Filter episode DataFrame
valid_tconsts = set(all_ratings['tconst'])
all_episodes = episode[
    episode['tconst'].isin(valid_tconsts) & episode['parentTconst'].isin(valid_tconsts)
]
print(all_episodes.shape, all_episodes.tconst.nunique(), all_episodes.parentTconst.nunique())

# Filter basics_ratings_merged DataFrame
all_ratings = all_ratings[
    all_ratings['tconst'].isin(all_episodes['tconst']) | all_ratings['tconst'].isin(all_episodes['parentTconst'])
]
print(all_ratings.shape)
# Out:
# (1500755, 11)
# (753424, 4) 753424 39225
# (792649, 11)

# %%
# prompt: in all_episodes, create all_series from all_episodes that only have rows with tconst in episode['parentTconst']. create all_episodes from all_episodes merge with all_ratings on all_episodes.tconst

# Create all_series from all_episodes
all_series = all_ratings[all_ratings['tconst'].isin(all_episodes['parentTconst'])]
print(all_series.shape)

# Create all_episodes from all_episodes merged with all_ratings
all_episodes = pd.merge(all_episodes, all_ratings, on='tconst', how='inner')
print(all_episodes.shape)
# Out:
# (39225, 11)
# (753424, 14)

# %%
all_series.head(3)
# Out:
#           tconst titleType       primaryTitle             originalTitle  \
# 22082  tt0039123  tvSeries      Kraft Theatre  Kraft Television Theatre
# 22083  tt0039125  tvSeries  Public Prosecutor         Public Prosecutor
# 22844  tt0040021  tvSeries     Actor's Studio            Actor's Studio
#
#        isAdult  startYear  endYear  runtimeMinutes                 genres  \
# 22082        0       1947     1958              60                  Drama
# 22083        0       1947     1951              20  Crime, Drama, Mystery
# 22844        0       1948     1950              30                  Drama
#
#        averageRating  numVotes
# 22082            7.9       233
# 22083            6.0        35
# 22844            7.1        94

# %%
all_series.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             Int64
# startYear           Int64
# endYear             Int64
# runtimeMinutes      Int64
# genres             object
# averageRating     float64
# numVotes            int64
# dtype: object

# %%
all_series.isna().sum()
# Out:
# tconst                0
# titleType             0
# primaryTitle          0
# originalTitle         0
# isAdult               0
# startYear             4
# endYear           14388
# runtimeMinutes    12786
# genres              228
# averageRating         0
# numVotes              0
# dtype: int64

# %%
all_episodes.head(2)
# Out:
#       tconst parentTconst  seasonNumber  episodeNumber  titleType  \
# 0  tt0041951    tt0041038             1              9  tvEpisode
# 1  tt0042816    tt0989125             1             17  tvEpisode
#
#      primaryTitle   originalTitle  isAdult  startYear  endYear  \
# 0  The Tenderfeet  The Tenderfeet        0       1949     <NA>
# 1         Othello         Othello        0       1950     <NA>
#
#    runtimeMinutes   genres  averageRating  numVotes
# 0              30  Western            7.6        99
# 1             143    Drama            7.6        12

# %%
all_episodes.dtypes
# Out:
# tconst             object
# parentTconst       object
# seasonNumber        int64
# episodeNumber       int64
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             Int64
# startYear           Int64
# endYear             Int64
# runtimeMinutes      Int64
# genres             object
# averageRating     float64
# numVotes            int64
# dtype: object

# %%
all_episodes.isna().sum()
# Out:
# tconst                 0
# parentTconst           0
# seasonNumber           0
# episodeNumber          0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear            149
# endYear           753424
# runtimeMinutes    295612
# genres              1003
# averageRating          0
# numVotes               0
# dtype: int64

# %%
all_episodes.to_csv('episodes.csv', index=False)
all_series.to_csv('series.csv', index=False)
